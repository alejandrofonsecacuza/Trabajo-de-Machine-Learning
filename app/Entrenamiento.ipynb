# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip /content/drive/MyDrive/datos_procesados.zip -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/images/00021968_001.png
#  extracting: /content/images/00016486_011.png
#  extracting: /content/images/00029813_037.png
#  extracting: /content/images/00002437_003_aug_174.png
#  extracting: /content/images/00028300_007.png
#  extracting: /content/images/00022106_006.png
#  extracting: /content/images/00010475_050.png
#  extracting: /content/images/00000034_000.png
#  extracting: /content/images/00029655_000.png
#  extracting: /content/images/00016420_000.png
#  extracting: /content/images/00000398_003.png
#  extracting: /content/images/00028702_000.png
#  extracting: /content/images/00028674_000.png
#  extracting: /content/images/00003292_007.png
#  extracting: /content/images/00014751_001.png
#  extracting: /content/images/00007932_005.png
#  extracting: /content/images/00023794_000.png
#  extracting: /content/images/00014370_000.png
#  extracting: /content/images/00004468_001.png
#  extracting: /content/images/00012225_000.png
#  extracting: /content/images/00019442_001.png
#  extracting: /content/images/00028521_000.png
#  extracting: /content/images/00017423_006.png
#  extracting: /content/images/00011571_007.png
#  extracting: /content/images/00009686_000.png
#  extracting: /content/images/00011460_002.png
#  extracting: /content/images/00002066_004.png
#  extracting: /content/images/00015658_000.png
#  extracting: /content/images/00014938_005.png
#  extracting: /content/images/00020436_001.png
#  extracting: /content/images/00007773_002.png
#  extracting: /content/images/00008709_000.png
#  extracting: /content/images/00015829_000.png
#  extracting: /content/images/00011460_006.png
#  extracting: /content/images/00022572_017.png
#  extracting: /content/images/00008368_000.png
#  extracting: /content/images/00017298_000.png
#  extracting: /content/images/00004833_013.png
#  extracting: /content/images/00006214_002.png
#  extracting: /content/images/00000159_000.png
#  extracting: /content/images/00002800_002.png
#  extracting: /content/images/00011237_054.png
#  extracting: /content/images/00004822_030.png
#  extracting: /content/images/00012415_001.png
#  extracting: /content/images/00004833_041.png
#  extracting: /content/images/00002572_004.png
#  extracting: /content/images/00005453_000.png
#  extracting: /content/images/00018233_053.png
#  extracting: /content/images/00007109_026.png
#  extracting: /content/images/00014808_000.png
#  extracting: /content/images/00001038_000.png
#  extracting: /content/images/00017470_000.png
#  extracting: /content/images/00025700_000.png
#  extracting: /content/images/00022335_003.png
#  extracting: /content/images/00026597_005.png
#  extracting: /content/images/00006621_001.png
#  extracting: /content/images/00016502_000.png
#  extracting: /content/images/00006024_001.png
#  extracting: /content/images/00007989_001.png
#  extracting: /content/images/00017606_043.png
#  extracting: /content/images/00005520_003.png
#  extracting: /content/images/00027677_001.png
#  extracting: /content/images/00008001_000.png
#  extracting: /content/images/00007806_004.png
#  extracting: /content/images/00009239_013.png
#  extracting: /content/images/00016333_004.png
#  extracting: /content/images/00027733_001.png
#  extracting: /content/images/00029763_011.png
#  extracting: /content/images/00025534_003.png
#  extracting: /content/images/00004822_040.png
#  extracting: /content/images/00029962_000.png
#  extracting: /content/images/00022570_000.png
#  extracting: /content/images/00009222_000.png
#  extracting: /content/images/00018733_001.png
#  extracting: /content/images/00012616_001.png
#  extracting: /content/images/00012230_000.png
#  extracting: /content/images/00015857_003.png
#  extracting: /content/images/00030218_003.png
#  extracting: /content/images/00017160_001.png
#  extracting: /content/images/00003996_009.png
#  extracting: /content/images/00018964_007.png
#  extracting: /content/images/00018019_002.png
#  extracting: /content/images/00018409_002.png
#  extracting: /content/images/00019643_032.png
#  extracting: /content/images/00020065_004.png
#  extracting: /content/images/00023065_023.png
#  extracting: /content/images/00000583_064.png
#  extracting: /content/images/00020741_000_aug_870.png
#  extracting: /content/images/00000324_012.png
#  extracting: /content/images/00018253_079.png
#  extracting: /content/images/00006192_013.png
#  extracting: /content/images/00025103_000.png
#  extracting: /content/images/00017362_021.png
#  extracting: /content/images/00018360_018.png
#  extracting: /content/images/00015236_000.png
#  extracting: /content/images/00004746_007.png
#  extracting: /content/images/00012354_000.png
#  extracting: /content/images/00023162_020.png
#  extracting: /content/images/00016486_013.png
#  extracting: /content/images/00000149_002.png
#  extracting: /content/images/00021888_002.png
#  extracting: /content/images/00010352_005.png
#  extracting: /content/images/00013844_002.png
#  extracting: /content/images/00005286_001.png
#  extracting: /content/images/00018166_002.png
#  extracting: /content/images/00028535_000.png
#  extracting: /content/images/00020629_009.png
#  extracting: /content/images/00017514_007.png
#  extracting: /content/images/00017691_005.png
#  extracting: /content/images/00000914_001.png
#  extracting: /content/images/00022899_005.png
#  extracting: /content/images/00001170_053.png
#  extracting: /content/images/00001170_044.png
#  extracting: /content/images/00014626_022.png
#  extracting: /content/images/00013925_004.png
#  extracting: /content/images/00017612_000.png
#  extracting: /content/images/00015915_000.png
#  extracting: /content/images/00001132_001.png
#  extracting: /content/images/00016801_004.png
#  extracting: /content/images/00014520_021.png
#  extracting: /content/images/00017036_019.png
#  extracting: /content/images/00008689_001.png
#  extracting: /content/images/00021990_004.png
#  extracting: /content/images/00002048_001.png
#  extracting: /content/images/00000144_000.png
#  extracting: /content/images/00025304_000.png
#  extracting: /content/images/00019694_000.png
#  extracting: /content/images/00009557_000.png
#  extracting: /content/images/00001855_010.png
#  extracting: /content/images/00007193_004.png
#  extracting: /content/images/00018840_013.png
#  extracting: /content/images/00002058_015.png
#  extracting: /content/images/00008015_000_aug_1049.png
#  extracting: /content/images/00020960_002.png
#  extracting: /content/images/00015041_003.png
#  extracting: /content/images/00026994_003.png
#  extracting: /content/images/00008691_002.png
#  extracting: /content/images/00001301_011.png
#  extracting: /content/images/00003459_016.png
#  extracting: /content/images/00016093_000.png
#  extracting: /content/images/00016587_078.png
#  extracting: /content/images/00013643_000.png
#  extracting: /content/images/00015687_001.png
#  extracting: /content/images/00004540_001.png
#  extracting: /content/images/00009729_001.png
#  extracting: /content/images/00017236_004.png
#  extracting: /content/images/00015087_004.png
#  extracting: /content/images/00008806_008.png
#  extracting: /content/images/00014565_004.png
#  extracting: /content/images/00005131_001.png
#  extracting: /content/images/00008532_000.png
#  extracting: /content/images/00012741_000.png
#  extracting: /content/images/00025017_001.png
#  extracting: /content/images/00023260_007.png
#  extracting: /content/images/00019124_062.png
#  extracting: /content/images/00029338_000.png
#  extracting: /content/images/00004563_000.png
#  extracting: /content/images/00015967_003.png
#  extracting: /content/images/00022075_001.png
#  extracting: /content/images/00001039_003.png
#  extracting: /content/images/00020161_000.png
#  extracting: /content/images/00007926_000.png
#  extracting: /content/images/00012108_000.png
#  extracting: /content/images/00017467_002.png
#  extracting: /content/images/00029809_003.png
#  extracting: /content/images/00010613_001.png
#  extracting: /content/images/00021455_009.png
#  extracting: /content/images/00029490_001.png
#  extracting: /content/images/00025202_001.png
#  extracting: /content/images/00019124_088.png
#  extracting: /content/images/00003489_001.png
#  extracting: /content/images/00010407_000.png
#  extracting: /content/images/00005819_000.png
#  extracting: /content/images/00003227_001.png
#  extracting: /content/images/00010007_102.png
#  extracting: /content/images/00000116_008.png
#  extracting: /content/images/00016191_022.png
#  extracting: /content/images/00008727_011.png
#  extracting: /content/images/00018245_005.png
#  extracting: /content/images/00009644_004.png
#  extracting: /content/images/00011830_000.png
#  extracting: /content/images/00005138_012.png
#  extracting: /content/images/00021025_000.png
#  extracting: /content/images/00016023_001.png
#  extracting: /content/images/00017691_020.png
#  extracting: /content/images/00003847_008.png
#  extracting: /content/images/00007455_003.png
#  extracting: /content/images/00023591_000.png
#  extracting: /content/images/00012659_033.png
#  extracting: /content/images/00008447_001_aug_1095.png
#  extracting: /content/images/00028433_018.png
#  extracting: /content/images/00030573_016.png
#  extracting: /content/images/00009397_010.png
#  extracting: /content/images/00012161_002.png
#  extracting: /content/images/00019585_000.png
#  extracting: /content/images/00001787_012.png
#  extracting: /content/images/00030567_000.png
#  extracting: /content/images/00013917_045.png
#  extracting: /content/images/00009638_020.png
#  extracting: /content/images/00025119_002.png
#  extracting: /content/images/00008875_011.png
#  extracting: /content/images/00000916_000.png
#  extracting: /content/images/00021164_005.png
#  extracting: /content/images/00002120_006.png
#  extracting: /content/images/00025510_000.png
#  extracting: /content/images/00021879_000_aug_285_aug_370.png
#  extracting: /content/images/00014792_001.png
#  extracting: /content/images/00007534_015.png
#  extracting: /content/images/00027939_000.png
#  extracting: /content/images/00016892_000.png
#  extracting: /content/images/00010007_152.png
#  extracting: /content/images/00030367_000.png
#  extracting: /content/images/00014760_002.png
#  extracting: /content/images/00011296_000.png
#  extracting: /content/images/00007645_001.png
#  extracting: /content/images/00020156_004.png
#  extracting: /content/images/00018074_001.png
#  extracting: /content/images/00022369_007.png
#  extracting: /content/images/00006602_000.png
#  extracting: /content/images/00029572_001.png
#  extracting: /content/images/00021663_006.png
#  extracting: /content/images/00009324_004.png
#  extracting: /content/images/00003028_037.png
#  extracting: /content/images/00010376_000.png
#  extracting: /content/images/00001822_000.png
#  extracting: /content/images/00012899_006.png
#  extracting: /content/images/00009781_000.png
#  extracting: /content/images/00016009_002.png
#  extracting: /content/images/00005266_001.png
#  extracting: /content/images/00014022_052.png
#  extracting: /content/images/00021584_006.png
#  extracting: /content/images/00025357_000.png
#  extracting: /content/images/00016126_000.png
#  extracting: /content/images/00029285_000.png
#  extracting: /content/images/00023358_000.png
#  extracting: /content/images/00006243_000.png
#  extracting: /content/images/00011925_003.png
#  extracting: /content/images/00017899_001.png
#  extracting: /content/images/00008296_000.png
#  extracting: /content/images/00002075_005.png
#  extracting: /content/images/00010782_000.png
#  extracting: /content/images/00005532_000.png
#  extracting: /content/images/00016210_000.png
#  extracting: /content/images/00012318_000.png
#  extracting: /content/images/00018390_007.png
#  extracting: /content/images/00010677_016.png
#  extracting: /content/images/00029888_000.png
#  extracting: /content/images/00017236_066.png
#  extracting: /content/images/00011003_011.png
#  extracting: /content/images/00021840_010.png
#  extracting: /content/images/00013031_001.png
#  extracting: /content/images/00002455_000.png
#  extracting: /content/images/00002666_002.png
#  extracting: /content/images/00011146_000.png
#  extracting: /content/images/00006219_000.png
#  extracting: /content/images/00009996_007.png
#  extracting: /content/images/00018724_013_aug_112.png
#  extracting: /content/images/00025085_014.png
#  extracting: /content/images/00014398_019.png
#  extracting: /content/images/00021734_003.png
#  extracting: /content/images/00018739_022.png
#  extracting: /content/images/00010367_000.png
#  extracting: /content/images/00010012_010.png
#  extracting: /content/images/00018187_048.png
#  extracting: /content/images/00008649_012.png
#  extracting: /content/images/00003938_001_aug_174.png
#  extracting: /content/images/00025628_019.png
#  extracting: /content/images/00004403_000.png
#  extracting: /content/images/00022815_024.png
#  extracting: /content/images/00011873_003.png
#  extracting: /content/images/00016434_009.png
#  extracting: /content/images/00019684_000.png
#  extracting: /content/images/00012625_005.png
#  extracting: /content/images/00012622_032.png
#  extracting: /content/images/00014827_009.png
#  extracting: /content/images/00002675_004.png
#  extracting: /content/images/00006082_000.png
#  extracting: /content/images/00011222_000.png
#  extracting: /content/images/00011915_005_aug_340.png
#  extracting: /content/images/00028294_000_aug_13.png
#  extracting: /content/images/00015068_007.png
#  extracting: /content/images/00028752_000.png
#  extracting: /content/images/00029703_000.png
#  extracting: /content/images/00016874_000.png
#  extracting: /content/images/00002640_002.png
#  extracting: /content/images/00016811_001.png
#  extracting: /content/images/00005166_000.png
#  extracting: /content/images/00001170_002.png
#  extracting: /content/images/00027044_000.png
#  extracting: /content/images/00003859_000.png
#  extracting: /content/images/00000709_005.png
#  extracting: /content/images/00026810_047.png
#  extracting: /content/images/00008081_018.png
#  extracting: /content/images/00018806_004.png
#  extracting: /content/images/00030064_002.png
#  extracting: /content/images/00026789_001.png
#  extracting: /content/images/00009181_000.png
#  extracting: /content/images/00022144_001.png
#  extracting: /content/images/00001582_011.png
#  extracting: /content/images/00001270_002.png
#  extracting: /content/images/00012480_002.png
#  extracting: /content/images/00017405_035.png
#  extracting: /content/images/00004738_000.png
#  extracting: /content/images/00024541_000.png
#  extracting: /content/images/00021392_000.png
#  extracting: /content/images/00018258_001.png
#  extracting: /content/images/00015770_042.png
#  extracting: /content/images/00016341_005.png
#  extracting: /content/images/00000176_001.png
#  extracting: /content/images/00013542_001.png
#  extracting: /content/images/00029279_006.png
#  extracting: /content/images/00012368_001.png
#  extracting: /content/images/00005772_001.png
#  extracting: /content/images/00018044_000.png
#  extracting: /content/images/00021217_000.png
#  extracting: /content/images/00003426_027.png
#  extracting: /content/images/00016052_003.png
#  extracting: /content/images/00008693_000.png
#  extracting: /content/images/00022192_038.png
#  extracting: /content/images/00000322_013.png
#  extracting: /content/images/00019924_044.png
#  extracting: /content/images/00013312_002.png
#  extracting: /content/images/00002639_011.png
#  extracting: /content/images/00007234_000.png
#  extracting: /content/images/00021114_001.png
#  extracting: /content/images/00020405_012.png
#  extracting: /content/images/00018044_047.png
#  extracting: /content/images/00008067_011.png
#  extracting: /content/images/00022415_006.png
#  extracting: /content/images/00004833_033.png
#  extracting: /content/images/00007423_000.png
#  extracting: /content/images/00002120_005.png
#  extracting: /content/images/00000997_003.png
#  extracting: /content/images/00026353_002.png
#  extracting: /content/images/00017852_000.png
#  extracting: /content/images/00001088_018.png
#  extracting: /content/images/00001944_000.png
#  extracting: /content/images/00021118_000.png
#  extracting: /content/images/00017515_001.png
#  extracting: /content/images/00015180_001.png
#  extracting: /content/images/00003001_001.png
#  extracting: /content/images/00004541_002.png
#  extracting: /content/images/00027324_000.png
#  extracting: /content/images/00010792_003.png
#  extracting: /content/images/00012057_014.png
#  extracting: /content/images/00004613_000.png
#  extracting: /content/images/00013791_000_aug_896.png
#  extracting: /content/images/00005372_022.png
#  extracting: /content/images/00023113_000.png
#  extracting: /content/images/00021200_005.png
#  extracting: /content/images/00026538_032.png
#  extracting: /content/images/00011428_008.png
#  extracting: /content/images/00024437_000.png
#  extracting: /content/images/00002860_016.png
#  extracting: /content/images/00002019_000.png
#  extracting: /content/images/00019150_011.png
#  extracting: /content/images/00024949_000.png
#  extracting: /content/images/00022572_049.png
#  extracting: /content/images/00012277_004.png
#  extracting: /content/images/00007135_000.png
#  extracting: /content/images/00015894_001.png
#  extracting: /content/images/00014571_012.png
#  extracting: /content/images/00025849_008.png
#  extracting: /content/images/00025633_001.png
#  extracting: /content/images/00014034_010.png
#  extracting: /content/images/00022146_000.png
#  extracting: /content/images/00011391_000.png
#  extracting: /content/images/00012973_016.png
#  extracting: /content/images/00016971_006.png
#  extracting: /content/images/00020292_000.png
#  extracting: /content/images/00010721_000.png
#  extracting: /content/images/00001854_002.png
#  extracting: /content/images/00022188_001.png
#  extracting: /content/images/00020408_040.png
#  extracting: /content/images/00020046_003.png
#  extracting: /content/images/00004858_053.png
#  extracting: /content/images/00026139_002.png
#  extracting: /content/images/00010052_003.png
#  extracting: /content/images/00000845_002.png
#  extracting: /content/images/00010293_001.png
#  extracting: /content/images/00028523_001.png
#  extracting: /content/images/00000013_041.png
#  extracting: /content/images/00019542_001.png
#  extracting: /content/images/00017138_028.png
#  extracting: /content/images/00025628_025.png
#  extracting: /content/images/00029336_000.png
#  extracting: /content/images/00006008_007.png
#  extracting: /content/images/00000709_002.png
#  extracting: /content/images/00019443_000.png
#  extracting: /content/images/00014085_007.png
#  extracting: /content/images/00014004_026.png
#  extracting: /content/images/00013430_007.png
#  extracting: /content/images/00013305_000.png
#  extracting: /content/images/00017819_005.png
#  extracting: /content/images/00012219_010.png
#  extracting: /content/images/00022816_004.png
#  extracting: /content/images/00030599_000.png
#  extracting: /content/images/00001833_013.png
#  extracting: /content/images/00027725_043.png
#  extracting: /content/images/00009960_001.png
#  extracting: /content/images/00028103_000.png
#  extracting: /content/images/00020393_006.png
#  extracting: /content/images/00017976_001.png
#  extracting: /content/images/00003569_001.png
#  extracting: /content/images/00002316_010.png
#  extracting: /content/images/00021303_012.png
#  extracting: /content/images/00018366_015.png
#  extracting: /content/images/00026389_002_aug_807.png
#  extracting: /content/images/00008745_001.png
#  extracting: /content/images/00001736_034.png
#  extracting: /content/images/00028784_001.png
#  extracting: /content/images/00002437_035.png
#  extracting: /content/images/00014614_000.png
#  extracting: /content/images/00020398_018.png
#  extracting: /content/images/00003089_001.png
#  extracting: /content/images/00004917_008.png
#  extracting: /content/images/00006056_001.png
#  extracting: /content/images/00026753_014.png
#  extracting: /content/images/00017677_000.png
#  extracting: /content/images/00020806_000.png
#  extracting: /content/images/00002840_002.png
#  extracting: /content/images/00000716_003.png
#  extracting: /content/images/00030548_000.png
#  extracting: /content/images/00028876_018.png
#  extracting: /content/images/00010509_000.png
#  extracting: /content/images/00012181_000.png
#  extracting: /content/images/00026466_000.png
#  extracting: /content/images/00002962_000.png
#  extracting: /content/images/00013283_003.png
#  extracting: /content/images/00005219_000.png
#  extracting: /content/images/00015758_003.png
#  extracting: /content/images/00003768_001.png
#  extracting: /content/images/00005346_001.png
#  extracting: /content/images/00005066_065.png
#  extracting: /content/images/00003785_002.png
#  extracting: /content/images/00030445_000.png
#  extracting: /content/images/00000372_009.png
#  extracting: /content/images/00002986_001.png
#  extracting: /content/images/00016184_013.png
#  extracting: /content/images/00006949_002.png
#  extracting: /content/images/00016280_003.png
#  extracting: /content/images/00024411_000.png
#  extracting: /content/images/00025432_000.png
#  extracting: /content/images/00006920_000.png
#  extracting: /content/images/00019837_000.png
#  extracting: /content/images/00014046_006.png
#  extracting: /content/images/00019369_004.png
#  extracting: /content/images/00018244_000.png
#  extracting: /content/images/00008990_001.png
#  extracting: /content/images/00006462_004.png
#  extracting: /content/images/00030254_001.png
#  extracting: /content/images/00008282_000.png
#  extracting: /content/images/00006566_000.png
#  extracting: /content/images/00025443_004.png
#  extracting: /content/images/00025451_002.png
#  extracting: /content/images/00016074_009.png
#  extracting: /content/images/00017942_002.png
#  extracting: /content/images/00027073_000.png
#  extracting: /content/images/00020496_000.png
#  extracting: /content/images/00022192_020.png
#  extracting: /content/images/00010914_000.png
#  extracting: /content/images/00019643_034.png
#  extracting: /content/images/00013512_001.png
#  extracting: /content/images/00002785_003.png
#  extracting: /content/images/00003957_001.png
#  extracting: /content/images/00020939_000.png
#  extracting: /content/images/00010324_000.png
#  extracting: /content/images/00004461_014.png
#  extracting: /content/images/00016410_049.png
#  extracting: /content/images/00008952_002.png
#  extracting: /content/images/00025769_023.png
#  extracting: /content/images/00000680_000.png
#  extracting: /content/images/00021485_003.png
#  extracting: /content/images/00014223_027.png
#  extracting: /content/images/00023310_001.png
#  extracting: /content/images/00028813_000.png
#  extracting: /content/images/00001378_002.png
#  extracting: /content/images/00003510_002.png
#  extracting: /content/images/00000496_000.png
#  extracting: /content/images/00002708_000.png
#  extracting: /content/images/00023316_003.png
#  extracting: /content/images/00026278_003.png
#  extracting: /content/images/00005629_000.png
#  extracting: /content/images/00001836_082.png
#  extracting: /content/images/00024306_000.png
#  extracting: /content/images/00023923_000.png
#  extracting: /content/images/00011005_000.png
#  extracting: /content/images/00013354_000.png
#  extracting: /content/images/00030796_000.png
#  extracting: /content/images/00014558_010.png
#  extracting: /content/images/00003159_001.png
#  extracting: /content/images/00013245_000.png
#  extracting: /content/images/00013334_000.png
#  extracting: /content/images/00006044_006.png
#  extracting: /content/images/00015509_000.png
#  extracting: /content/images/00005763_001.png
#  extracting: /content/images/00006713_002.png
#  extracting: /content/images/00000123_000.png
#  extracting: /content/images/00008269_006_aug_186.png
#  extracting: /content/images/00007532_002.png
#  extracting: /content/images/00001368_001.png
#  extracting: /content/images/00025303_036.png
#  extracting: /content/images/00013670_115.png
#  extracting: /content/images/00016044_001.png
#  extracting: /content/images/00023075_036.png
#  extracting: /content/images/00010944_000.png
#  extracting: /content/images/00001594_000.png
#  extracting: /content/images/00030183_005.png
#  extracting: /content/images/00005502_014.png
#  extracting: /content/images/00016167_003.png
#  extracting: /content/images/00015879_001.png
#  extracting: /content/images/00028722_000.png
#  extracting: /content/images/00017407_000.png
#  extracting: /content/images/00001140_004_aug_227.png
#  extracting: /content/images/00022248_000.png
#  extracting: /content/images/00017070_002.png
#  extracting: /content/images/00029188_001_aug_1138.png
#  extracting: /content/images/00007937_001.png
#  extracting: /content/images/00010762_000.png
#  extracting: /content/images/00013792_000.png
#  extracting: /content/images/00025700_001.png
#  extracting: /content/images/00013847_000.png
#  extracting: /content/images/00025444_007.png
#  extracting: /content/images/00005679_004.png
#  extracting: /content/images/00007700_000.png
#  extracting: /content/images/00002803_009.png
#  extracting: /content/images/00027775_002.png
#  extracting: /content/images/00027311_002.png
#  extracting: /content/images/00017453_000.png
#  extracting: /content/images/00010012_019.png
#  extracting: /content/images/00029688_004.png
#  extracting: /content/images/00019373_012.png
#  extracting: /content/images/00011925_023.png
#  extracting: /content/images/00008956_000.png
#  extracting: /content/images/00013402_000.png
#  extracting: /content/images/00019019_001.png
#  extracting: /content/images/00006096_008.png
#  extracting: /content/images/00003523_013.png
#  extracting: /content/images/00009724_001.png
#  extracting: /content/images/00019124_039.png
#  extracting: /content/images/00018840_002.png
#  extracting: /content/images/00005069_020.png
#  extracting: /content/images/00007557_027.png
#  extracting: /content/images/00015556_026.png
#  extracting: /content/images/00002414_000.png
#  extracting: /content/images/00028582_009.png
#  extracting: /content/images/00021618_000.png
#  extracting: /content/images/00025628_000.png
#  extracting: /content/images/00003954_000.png
#  extracting: /content/images/00014604_003.png
#  extracting: /content/images/00002633_010.png
#  extracting: /content/images/00013085_001.png
#  extracting: /content/images/00019386_002.png
#  extracting: /content/images/00016732_026.png
#  extracting: /content/images/00012203_000.png
#  extracting: /content/images/00002111_003.png
#  extracting: /content/images/00014849_010.png
#  extracting: /content/images/00008500_000.png
#  extracting: /content/images/00002817_003.png
#  extracting: /content/images/00016384_000.png
#  extracting: /content/images/00012879_003.png
#  extracting: /content/images/00024356_000.png
#  extracting: /content/images/00011379_042.png
#  extracting: /content/images/00015041_013.png
#  extracting: /content/images/00022001_000.png
#  extracting: /content/images/00018065_004.png
#  extracting: /content/images/00016189_002.png
#  extracting: /content/images/00008185_003.png
#  extracting: /content/images/00013036_008.png
#  extracting: /content/images/00003392_006.png
#  extracting: /content/images/00012728_000.png
#  extracting: /content/images/00002763_019.png
#  extracting: /content/images/00001674_000.png
#  extracting: /content/images/00010334_017.png
#  extracting: /content/images/00021075_000.png
#  extracting: /content/images/00009574_014.png
#  extracting: /content/images/00028692_000.png
#  extracting: /content/images/00015814_008.png
#  extracting: /content/images/00017984_000.png
#  extracting: /content/images/00001726_000.png
#  extracting: /content/images/00005020_001.png
#  extracting: /content/images/00003970_001.png
#  extracting: /content/images/00021073_007.png
#  extracting: /content/images/00007909_005.png
#  extracting: /content/images/00019141_000.png
#  extracting: /content/images/00011528_000.png
#  extracting: /content/images/00019594_005.png
#  extracting: /content/images/00008761_000.png
#  extracting: /content/images/00004857_047.png
#  extracting: /content/images/00016443_007.png
#  extracting: /content/images/00028633_000.png
#  extracting: /content/images/00010243_003.png
#  extracting: /content/images/00020284_000.png
#  extracting: /content/images/00006033_003.png
#  extracting: /content/images/00024824_000.png
#  extracting: /content/images/00029817_020.png
#  extracting: /content/images/00027039_004.png
#  extracting: /content/images/00010207_002.png
#  extracting: /content/images/00000820_023.png
#  extracting: /content/images/00000199_004.png
#  extracting: /content/images/00003938_001_aug_1658.png
#  extracting: /content/images/00023254_003.png
#  extracting: /content/images/00019935_008.png
#  extracting: /content/images/00019124_031.png
#  extracting: /content/images/00008535_001.png
#  extracting: /content/images/00008476_000.png
#  extracting: /content/images/00002479_000.png
#  extracting: /content/images/00001247_014.png
#  extracting: /content/images/00022329_005.png
#  extracting: /content/images/00000870_007.png
#  extracting: /content/images/00029817_024_aug_239.png
#  extracting: /content/images/00011357_000.png
#  extracting: /content/images/00016258_004.png
#  extracting: /content/images/00004652_001.png
#  extracting: /content/images/00019363_015.png
#  extracting: /content/images/00005213_000.png
#  extracting: /content/images/00029399_000.png
#  extracting: /content/images/00005761_000.png
#  extracting: /content/images/00008806_015.png
#  extracting: /content/images/00030765_000.png
#  extracting: /content/images/00007340_006.png
#  extracting: /content/images/00001248_031.png
#  extracting: /content/images/00013380_006_aug_1398.png
#  extracting: /content/images/00029135_003.png
#  extracting: /content/images/00023296_005.png
#  extracting: /content/images/00010897_012.png
#  extracting: /content/images/00009459_007.png
#  extracting: /content/images/00019530_016.png
#  extracting: /content/images/00019363_030.png
#  extracting: /content/images/00013090_000.png
#  extracting: /content/images/00009641_008.png
#  extracting: /content/images/00015905_000.png
#  extracting: /content/images/00029976_008.png
#  extracting: /content/images/00027385_000.png
#  extracting: /content/images/00009993_009.png
#  extracting: /content/images/00008067_015.png
#  extracting: /content/images/00023173_002.png
#  extracting: /content/images/00029221_000.png
#  extracting: /content/images/00010936_026.png
#  extracting: /content/images/00020046_007.png
#  extracting: /content/images/00008406_000.png
#  extracting: /content/images/00020408_009.png
#  extracting: /content/images/00013417_000.png
#  extracting: /content/images/00009638_000.png
#  extracting: /content/images/00009079_000.png
#  extracting: /content/images/00020020_006.png
#  extracting: /content/images/00022713_003.png
#  extracting: /content/images/00017126_003.png
#  extracting: /content/images/00011145_003.png
#  extracting: /content/images/00000569_002.png
#  extracting: /content/images/00018304_010.png
#  extracting: /content/images/00014149_005.png
#  extracting: /content/images/00006480_003.png
#  extracting: /content/images/00015732_038.png
#  extracting: /content/images/00019860_008.png
#  extracting: /content/images/00006320_000.png
#  extracting: /content/images/00014160_000.png
#  extracting: /content/images/00024177_000.png
#  extracting: /content/images/00002131_001.png
#  extracting: /content/images/00020631_000.png
#  extracting: /content/images/00004092_001.png
#  extracting: /content/images/00026412_050.png
#  extracting: /content/images/00003681_002.png
#  extracting: /content/images/00000165_005.png
#  extracting: /content/images/00019894_003.png
#  extracting: /content/images/00001809_003.png
#  extracting: /content/images/00021988_004.png
#  extracting: /content/images/00008274_002.png
#  extracting: /content/images/00018656_001.png
#  extracting: /content/images/00016270_012.png
#  extracting: /content/images/00004268_011.png
#  extracting: /content/images/00004959_006.png
#  extracting: /content/images/00028796_000.png
#  extracting: /content/images/00025959_000.png
#  extracting: /content/images/00027431_000.png
#  extracting: /content/images/00010028_007.png
#  extracting: /content/images/00022594_000.png
#  extracting: /content/images/00029548_012.png
#  extracting: /content/images/00002361_013.png
#  extracting: /content/images/00018950_000.png
#  extracting: /content/images/00004261_000.png
#  extracting: /content/images/00019530_012.png
#  extracting: /content/images/00007624_051.png
#  extracting: /content/images/00020349_005.png
#  extracting: /content/images/00002256_012.png
#  extracting: /content/images/00006275_000.png
#  extracting: /content/images/00024570_000.png
#  extracting: /content/images/00017565_000.png
#  extracting: /content/images/00019407_005_aug_341.png
#  extracting: /content/images/00011692_000.png
#  extracting: /content/images/00014934_003.png
#  extracting: /content/images/00029391_000.png
#  extracting: /content/images/00002360_001.png
#  extracting: /content/images/00022792_000.png
#  extracting: /content/images/00000512_001.png
#  extracting: /content/images/00003648_000.png
#  extracting: /content/images/00008678_005.png
#  extracting: /content/images/00004040_001.png
#  extracting: /content/images/00002580_004.png
#  extracting: /content/images/00016213_010.png
#  extracting: /content/images/00014945_007.png
#  extracting: /content/images/00021942_006.png
#  extracting: /content/images/00027592_004.png
#  extracting: /content/images/00016587_069.png
#  extracting: /content/images/00030322_001.png
#  extracting: /content/images/00025315_000.png
#  extracting: /content/images/00019637_010.png
#  extracting: /content/images/00020945_032.png
#  extracting: /content/images/00021276_006.png
#  extracting: /content/images/00011187_004.png
#  extracting: /content/images/00003094_003.png
#  extracting: /content/images/00021173_004.png
#  extracting: /content/images/00027260_018.png
#  extracting: /content/images/00018434_000.png
#  extracting: /content/images/00026428_001.png
#  extracting: /content/images/00018719_000.png
#  extracting: /content/images/00022938_000.png
#  extracting: /content/images/00001170_050.png
#  extracting: /content/images/00011619_005.png
#  extracting: /content/images/00001940_001.png
#  extracting: /content/images/00011667_000.png
#  extracting: /content/images/00001152_001.png
#  extracting: /content/images/00012413_006.png
#  extracting: /content/images/00010066_001.png
#  extracting: /content/images/00029701_002.png
#  extracting: /content/images/00025612_004.png
#  extracting: /content/images/00004893_049.png
#  extracting: /content/images/00004547_015.png
#  extracting: /content/images/00023286_003.png
#  extracting: /content/images/00009798_012.png
#  extracting: /content/images/00023176_014.png
#  extracting: /content/images/00023830_000.png
#  extracting: /content/images/00016484_005.png
#  extracting: /content/images/00006889_003.png
#  extracting: /content/images/00011695_003.png
#  extracting: /content/images/00001549_007.png
#  extracting: /content/images/00000756_000.png
#  extracting: /content/images/00009367_003.png
#  extracting: /content/images/00005577_000.png
#  extracting: /content/images/00012646_005.png
#  extracting: /content/images/00003185_001.png
#  extracting: /content/images/00027534_000.png
#  extracting: /content/images/00008033_007.png
#  extracting: /content/images/00027168_004.png
#  extracting: /content/images/00000003_002_aug_221.png
#  extracting: /content/images/00012412_000.png
#  extracting: /content/images/00001483_019.png
#  extracting: /content/images/00018246_001.png
#  extracting: /content/images/00002424_011.png
#  extracting: /content/images/00005395_011.png
#  extracting: /content/images/00006996_014.png
#  extracting: /content/images/00019694_003.png
#  extracting: /content/images/00005962_011.png
#  extracting: /content/images/00015081_009.png
#  extracting: /content/images/00030702_000.png
#  extracting: /content/images/00003053_005_aug_235.png
#  extracting: /content/images/00030172_000.png
#  extracting: /content/images/00019039_000.png
#  extracting: /content/images/00003392_032.png
#  extracting: /content/images/00009403_003.png
#  extracting: /content/images/00009281_010.png
#  extracting: /content/images/00019547_008.png
#  extracting: /content/images/00008034_001.png
#  extracting: /content/images/00010319_004.png
#  extracting: /content/images/00025452_000.png
#  extracting: /content/images/00007466_000.png
#  extracting: /content/images/00022031_012.png
#  extracting: /content/images/00017017_009.png
#  extracting: /content/images/00006480_001.png
#  extracting: /content/images/00027084_000.png
#  extracting: /content/images/00006783_009.png
#  extracting: /content/images/00003978_000.png
#  extracting: /content/images/00027809_006.png
#  extracting: /content/images/00024250_000.png
#  extracting: /content/images/00013922_026.png
#  extracting: /content/images/00030020_000.png
#  extracting: /content/images/00004427_001.png
#  extracting: /content/images/00004822_049.png
#  extracting: /content/images/00015075_002.png
#  extracting: /content/images/00004888_002.png
#  extracting: /content/images/00002529_015.png
#  extracting: /content/images/00023601_004.png
#  extracting: /content/images/00028357_031.png
#  extracting: /content/images/00010157_005.png
#  extracting: /content/images/00028285_010.png
#  extracting: /content/images/00025825_002.png
#  extracting: /content/images/00021222_010.png
#  extracting: /content/images/00016608_000.png
#  extracting: /content/images/00022622_008.png
#  extracting: /content/images/00003866_003.png
#  extracting: /content/images/00014996_007.png
#  extracting: /content/images/00029809_004.png
#  extracting: /content/images/00030510_000.png
#  extracting: /content/images/00008462_006.png
#  extracting: /content/images/00019348_010.png
#  extracting: /content/images/00009595_001.png
#  extracting: /content/images/00003453_000.png
#  extracting: /content/images/00013641_021.png
#  extracting: /content/images/00027572_003.png
#  extracting: /content/images/00005448_020.png
#  extracting: /content/images/00003312_000.png
#  extracting: /content/images/00025712_000.png
#  extracting: /content/images/00009851_001.png
#  extracting: /content/images/00009343_003.png
#  extracting: /content/images/00021264_001.png
#  extracting: /content/images/00019088_000_aug_625.png
#  extracting: /content/images/00008652_000.png
#  extracting: /content/images/00015630_000.png
#  extracting: /content/images/00020187_002.png
#  extracting: /content/images/00009507_015_aug_172.png
#  extracting: /content/images/00018483_005.png
#  extracting: /content/images/00006365_000.png
#  extracting: /content/images/00002487_001.png
#  extracting: /content/images/00009752_001.png
#  extracting: /content/images/00008355_000.png
#  extracting: /content/images/00013055_008.png
#  extracting: /content/images/00023604_003.png
#  extracting: /content/images/00021035_041.png
#  extracting: /content/images/00004109_001.png
#  extracting: /content/images/00008841_049.png
#  extracting: /content/images/00025149_001.png
#  extracting: /content/images/00013111_094.png
#  extracting: /content/images/00010454_008.png
#  extracting: /content/images/00019278_000.png
#  extracting: /content/images/00003659_011.png
#  extracting: /content/images/00021061_000.png
#  extracting: /content/images/00020680_005.png
#  extracting: /content/images/00005202_002.png
#  extracting: /content/images/00016618_009.png
#  extracting: /content/images/00019576_000.png
#  extracting: /content/images/00017111_001.png
#  extracting: /content/images/00023323_003.png
#  extracting: /content/images/00009953_017.png
#  extracting: /content/images/00010590_010.png
#  extracting: /content/images/00023342_001.png
#  extracting: /content/images/00012364_027.png
#  extracting: /content/images/00006284_002.png
#  extracting: /content/images/00007009_003.png
#  extracting: /content/images/00013380_013_aug_1767.png
#  extracting: /content/images/00015563_014.png
#  extracting: /content/images/00023343_000.png
#  extracting: /content/images/00004470_003.png
#  extracting: /content/images/00017236_029.png
#  extracting: /content/images/00006308_002.png
#  extracting: /content/images/00001836_080.png
#  extracting: /content/images/00015556_008.png
#  extracting: /content/images/00012021_012.png
#  extracting: /content/images/00010872_002.png
#  extracting: /content/images/00011514_000.png
#  extracting: /content/images/00003153_001.png
#  extracting: /content/images/00016971_031.png
#  extracting: /content/images/00022260_000.png
#  extracting: /content/images/00009545_000.png
#  extracting: /content/images/00003938_001_aug_810.png
#  extracting: /content/images/00011723_037.png
#  extracting: /content/images/00023662_000.png
#  extracting: /content/images/00018660_004.png
#  extracting: /content/images/00020318_028.png
#  extracting: /content/images/00003029_005_aug_1483.png
#  extracting: /content/images/00019813_000.png
#  extracting: /content/images/00006096_003.png
#  extracting: /content/images/00004492_000.png
#  extracting: /content/images/00014683_000.png
#  extracting: /content/images/00015013_004.png
#  extracting: /content/images/00004470_010.png
#  extracting: /content/images/00012892_001.png
#  extracting: /content/images/00013475_000.png
#  extracting: /content/images/00021067_000.png
#  extracting: /content/images/00019449_000.png
#  extracting: /content/images/00006304_029.png
#  extracting: /content/images/00013992_001.png
#  extracting: /content/images/00028992_000.png
#  extracting: /content/images/00015082_002.png
#  extracting: /content/images/00015758_004.png
#  extracting: /content/images/00018944_002.png
#  extracting: /content/images/00030698_000.png
#  extracting: /content/images/00019677_003.png
#  extracting: /content/images/00021499_027.png
#  extracting: /content/images/00013832_000.png
#  extracting: /content/images/00017429_006.png
#  extracting: /content/images/00008142_002.png
#  extracting: /content/images/00020524_021.png
#  extracting: /content/images/00013060_002.png
#  extracting: /content/images/00019729_000.png
#  extracting: /content/images/00020617_001.png
#  extracting: /content/images/00026050_010.png
#  extracting: /content/images/00023584_000.png
#  extracting: /content/images/00007885_003.png
#  extracting: /content/images/00006875_021.png
#  extracting: /content/images/00013601_022.png
#  extracting: /content/images/00016399_014.png
#  extracting: /content/images/00003684_002.png
#  extracting: /content/images/00000416_001.png
#  extracting: /content/images/00004959_010.png
#  extracting: /content/images/00003529_000.png
#  extracting: /content/images/00006498_001.png
#  extracting: /content/images/00017579_000.png
#  extracting: /content/images/00013765_004.png
#  extracting: /content/images/00023162_001.png
#  extracting: /content/images/00000251_001.png
#  extracting: /content/images/00024016_000.png
#  extracting: /content/images/00014352_003.png
#  extracting: /content/images/00011501_000.png
#  extracting: /content/images/00010563_003.png
#  extracting: /content/images/00004006_009.png
#  extracting: /content/images/00001122_011.png
#  extracting: /content/images/00007632_006.png
#  extracting: /content/images/00015893_005.png
#  extracting: /content/images/00029350_000.png
#  extracting: /content/images/00001297_001.png
#  extracting: /content/images/00002675_007.png
#  extracting: /content/images/00021041_004.png
#  extracting: /content/images/00028078_000.png
#  extracting: /content/images/00011802_004.png
#  extracting: /content/images/00025263_001.png
#  extracting: /content/images/00013992_006.png
#  extracting: /content/images/00014018_012.png
#  extracting: /content/images/00025228_002.png
#  extracting: /content/images/00013575_001.png
#  extracting: /content/images/00009652_001.png
#  extracting: /content/images/00020326_057.png
#  extracting: /content/images/00025707_018.png
#  extracting: /content/images/00029763_000.png
#  extracting: /content/images/00000181_047.png
#  extracting: /content/images/00005879_000.png
#  extracting: /content/images/00015799_009.png
#  extracting: /content/images/00012087_020.png
#  extracting: /content/images/00012372_000.png
#  extracting: /content/images/00021886_003.png
#  extracting: /content/images/00001895_002.png
#  extracting: /content/images/00001100_000.png
#  extracting: /content/images/00001984_010.png
#  extracting: /content/images/00004750_003.png
#  extracting: /content/images/00006146_000.png
#  extracting: /content/images/00004340_002.png
#  extracting: /content/images/00008975_000.png
#  extracting: /content/images/00021035_009.png
#  extracting: /content/images/00017603_004.png
#  extracting: /content/images/00002633_008.png
#  extracting: /content/images/00000290_000.png
#  extracting: /content/images/00022454_008.png
#  extracting: /content/images/00006472_004.png
#  extracting: /content/images/00015113_009.png
#  extracting: /content/images/00026721_000.png
#  extracting: /content/images/00005328_000.png
#  extracting: /content/images/00021782_019.png
#  extracting: /content/images/00005026_000.png
#  extracting: /content/images/00001203_018.png
#  extracting: /content/images/00017575_000.png
#  extracting: /content/images/00020810_001.png
#  extracting: /content/images/00016875_001.png
#  extracting: /content/images/00013219_013.png
#  extracting: /content/images/00012161_008.png
#  extracting: /content/images/00013623_007.png
#  extracting: /content/images/00001751_001.png
#  extracting: /content/images/00007624_017.png
#  extracting: /content/images/00019522_000.png
#  extracting: /content/images/00018044_031.png
#  extracting: /content/images/00018944_003.png
#  extracting: /content/images/00010315_003.png
#  extracting: /content/images/00012152_000.png
#  extracting: /content/images/00015646_014.png
#  extracting: /content/images/00002772_000.png
#  extracting: /content/images/00008911_020.png
#  extracting: /content/images/00029317_000.png
#  extracting: /content/images/00018371_001.png
#  extracting: /content/images/00025317_003.png
#  extracting: /content/images/00012672_003.png
#  extracting: /content/images/00009365_013.png
#  extracting: /content/images/00017947_016.png
#  extracting: /content/images/00029883_003.png
#  extracting: /content/images/00011020_000.png
#  extracting: /content/images/00012205_000.png
#  extracting: /content/images/00009166_015.png
#  extracting: /content/images/00014981_002.png
#  extracting: /content/images/00022776_014.png
#  extracting: /content/images/00018657_016.png
#  extracting: /content/images/00027036_001.png
#  extracting: /content/images/00001248_003.png
#  extracting: /content/images/00030411_000.png
#  extracting: /content/images/00026848_021.png
#  extracting: /content/images/00012815_008.png
#  extracting: /content/images/00023325_010.png
#  extracting: /content/images/00007007_003.png
#  extracting: /content/images/00005448_011.png
#  extracting: /content/images/00015852_005.png
#  extracting: /content/images/00025984_000.png
#  extracting: /content/images/00000980_000.png
#  extracting: /content/images/00015280_001.png
#  extracting: /content/images/00012291_001.png
#  extracting: /content/images/00000039_003.png
#  extracting: /content/images/00010007_040.png
#  extracting: /content/images/00027320_016.png
#  extracting: /content/images/00029281_000.png
# ...
#  extracting: /content/images/00014659_000.png
#  extracting: /content/images/00010625_007.png
#  extracting: /content/images/00001059_008.png
#  extracting: /content/images/00014950_003.png
#  extracting: /content/images/00010465_001.png
#  extracting: /content/images/00017736_000.png
#  extracting: /content/images/00015833_002.png
#  extracting: /content/images/00021047_020.png
#  extracting: /content/images/00004239_000.png
#  extracting: /content/images/00005993_009.png
#  extracting: /content/images/00017981_013.png
#  extracting: /content/images/00011308_000.png
#  extracting: /content/images/00025447_001.png
#  extracting: /content/images/00028353_000.png
#  extracting: /content/images/00010995_009.png
#  extracting: /content/images/00003240_000_aug_916.png
#  extracting: /content/images/00000547_000.png
#  extracting: /content/images/00029503_000.png
#  extracting: /content/images/00009863_048.png
#  extracting: /content/images/00023542_000.png
#  extracting: /content/images/00012719_006.png
#  extracting: /content/images/00006906_008.png
#  extracting: /content/images/00011151_005.png
#  extracting: /content/images/00020290_012.png
#  extracting: /content/images/00007676_001.png
#  extracting: /content/images/00030553_000.png
#  extracting: /content/images/00004169_002.png
#  extracting: /content/images/00028624_004.png
#  extracting: /content/images/00012984_000.png
#  extracting: /content/images/00018739_024.png
#  extracting: /content/images/00009117_002.png
#  extracting: /content/images/00027685_007.png
#  extracting: /content/images/00011786_000.png
#  extracting: /content/images/00005131_002.png
#  extracting: /content/images/00030802_000.png
#  extracting: /content/images/00015425_008.png
#  extracting: /content/images/00007762_001.png
#  extracting: /content/images/00026293_000.png
#  extracting: /content/images/00026854_000.png
#  extracting: /content/images/00012804_004.png
#  extracting: /content/images/00010937_001.png
#  extracting: /content/images/00004542_000.png
#  extracting: /content/images/00002161_000.png
#  extracting: /content/images/00009411_000.png
#  extracting: /content/images/00015708_005.png
#  extracting: /content/images/00026132_024.png
#  extracting: /content/images/00000116_021.png
#  extracting: /content/images/00011598_034.png
#  extracting: /content/images/00017007_004.png
#  extracting: /content/images/00016143_005.png
#  extracting: /content/images/00009962_000.png
#  extracting: /content/images/00016789_014.png
#  extracting: /content/images/00021574_000.png
#  extracting: /content/images/00005756_006.png
#  extracting: /content/images/00013613_000.png
#  extracting: /content/images/00000539_000.png
#  extracting: /content/images/00014934_009.png
#  extracting: /content/images/00006443_000.png
#  extracting: /content/images/00020560_000.png
#  extracting: /content/images/00029714_000.png
#  extracting: /content/images/00029404_000.png
#  extracting: /content/images/00015572_010.png
#  extracting: /content/images/00022091_000.png
#  extracting: /content/images/00009574_027.png
#  extracting: /content/images/00013992_004.png
#  extracting: /content/images/00014883_000.png
#  extracting: /content/images/00007139_000.png
#  extracting: /content/images/00004006_071.png
#  extracting: /content/images/00023325_023.png
#  extracting: /content/images/00006359_001.png
#  extracting: /content/images/00013002_007.png
#  extracting: /content/images/00016122_011.png
#  extracting: /content/images/00011548_010.png
#  extracting: /content/images/00001125_002.png
#  extracting: /content/images/00011859_023.png
#  extracting: /content/images/00006875_031.png
#  extracting: /content/images/00013731_000.png
#  extracting: /content/images/00001101_013.png
#  extracting: /content/images/00020751_006.png
#  extracting: /content/images/00027177_002.png
#  extracting: /content/images/00008142_006.png
#  extracting: /content/images/00006936_007.png
#  extracting: /content/images/00015193_001.png
#  extracting: /content/images/00029058_002.png
#  extracting: /content/images/00001558_038.png
#  extracting: /content/images/00018778_001.png
#  extracting: /content/images/00016975_015.png
#  extracting: /content/images/00012086_004.png
#  extracting: /content/images/00001122_017.png
#  extracting: /content/images/00010060_030.png
#  extracting: /content/images/00008870_000.png
#  extracting: /content/images/00001039_004.png
#  extracting: /content/images/00018795_001.png
#  extracting: /content/images/00001182_004_aug_566.png
#  extracting: /content/images/00017933_004.png
#  extracting: /content/images/00009638_025.png
#  extracting: /content/images/00020290_008.png
#  extracting: /content/images/00000459_017.png
#  extracting: /content/images/00015843_019.png
#  extracting: /content/images/00021457_026.png
#  extracting: /content/images/00003736_002.png
#  extracting: /content/images/00028476_000.png
#  extracting: /content/images/00015443_012.png
#  extracting: /content/images/00018103_014.png
#  extracting: /content/images/00004404_004.png
#  extracting: /content/images/00011167_006.png
#  extracting: /content/images/00003162_000.png
#  extracting: /content/images/00013946_008.png
#  extracting: /content/images/00012071_000.png
#  extracting: /content/images/00014596_012.png
#  extracting: /content/images/00001483_014.png
#  extracting: /content/images/00015384_002.png
#  extracting: /content/images/00008467_000.png
#  extracting: /content/images/00010994_003.png
#  extracting: /content/images/00022378_000.png
#  extracting: /content/images/00011553_020.png
#  extracting: /content/images/00018387_019.png
#  extracting: /content/images/00012241_000.png
#  extracting: /content/images/00000199_001_aug_512.png
#  extracting: /content/images/00019643_031.png
#  extracting: /content/images/00002672_002.png
#  extracting: /content/images/00014150_000_aug_99.png
#  extracting: /content/images/00029663_007.png
#  extracting: /content/images/00005639_001.png
#  extracting: /content/images/00020675_003.png
#  extracting: /content/images/00010841_002.png
#  extracting: /content/images/00025165_000.png
#  extracting: /content/images/00004508_012.png
#  extracting: /content/images/00000831_005.png
#  extracting: /content/images/00001836_095.png
#  extracting: /content/images/00002763_013.png
#  extracting: /content/images/00008943_001.png
#  extracting: /content/images/00008694_003_aug_641.png
#  extracting: /content/images/00000489_006.png
#  extracting: /content/images/00010160_001.png
#  extracting: /content/images/00007152_007.png
#  extracting: /content/images/00011130_002.png
#  extracting: /content/images/00023835_000.png
#  extracting: /content/images/00015371_003.png
#  extracting: /content/images/00004381_001.png
#  extracting: /content/images/00002497_000.png
#  extracting: /content/images/00006102_023.png
#  extracting: /content/images/00012863_041.png
#  extracting: /content/images/00015530_089.png
#  extracting: /content/images/00016587_054.png
#  extracting: /content/images/00000096_002.png
#  extracting: /content/images/00002954_003.png
#  extracting: /content/images/00000761_007.png
#  extracting: /content/images/00026893_000.png
#  extracting: /content/images/00016434_006.png
#  extracting: /content/images/00001326_005.png
#  extracting: /content/images/00025639_000.png
#  extracting: /content/images/00011420_005.png
#  extracting: /content/images/00025207_000.png
#  extracting: /content/images/00006864_002.png
#  extracting: /content/images/00006300_000.png
#  extracting: /content/images/00003058_000.png
#  extracting: /content/images/00017470_003.png
#  extracting: /content/images/00007256_010.png
#  extracting: /content/images/00026272_000.png
#  extracting: /content/images/00014785_002.png
#  extracting: /content/images/00012021_055.png
#  extracting: /content/images/00012297_004.png
#  extracting: /content/images/00000627_029.png
#  extracting: /content/images/00004435_023.png
#  extracting: /content/images/00013594_037.png
#  extracting: /content/images/00021565_012.png
#  extracting: /content/images/00017914_005.png
#  extracting: /content/images/00023748_000.png
#  extracting: /content/images/00009963_008.png
#  extracting: /content/images/00019849_000.png
#  extracting: /content/images/00013205_001_aug_96.png
#  extracting: /content/images/00014363_000.png
#  extracting: /content/images/00000857_000.png
#  extracting: /content/images/00000248_015.png
#  extracting: /content/images/00016494_000.png
#  extracting: /content/images/00018904_002.png
#  extracting: /content/images/00017316_000.png
#  extracting: /content/images/00015732_041.png
#  extracting: /content/images/00028908_000.png
#  extracting: /content/images/00027703_000.png
#  extracting: /content/images/00010563_006.png
#  extracting: /content/images/00000825_002.png
#  extracting: /content/images/00006239_000.png
#  extracting: /content/images/00009691_008.png
#  extracting: /content/images/00009030_004.png
#  extracting: /content/images/00003506_001.png
#  extracting: /content/images/00001989_012.png
#  extracting: /content/images/00003393_041.png
#  extracting: /content/images/00026774_000.png
#  extracting: /content/images/00011619_003.png
#  extracting: /content/images/00018027_006.png
#  extracting: /content/images/00023138_005.png
#  extracting: /content/images/00001989_004_aug_400.png
#  extracting: /content/images/00017714_010.png
#  extracting: /content/images/00018260_005.png
#  extracting: /content/images/00020090_000.png
#  extracting: /content/images/00002000_000.png
#  extracting: /content/images/00026241_000.png
#  extracting: /content/images/00022533_002.png
#  extracting: /content/images/00015007_002.png
#  extracting: /content/images/00011686_001.png
#  extracting: /content/images/00026336_003.png
#  extracting: /content/images/00005504_006.png
#  extracting: /content/images/00020259_000.png
#  extracting: /content/images/00029734_000.png
#  extracting: /content/images/00012094_013.png
#  extracting: /content/images/00005462_000.png
#  extracting: /content/images/00022380_002.png
#  extracting: /content/images/00001504_014.png
#  extracting: /content/images/00030270_000.png
#  extracting: /content/images/00029959_001.png
#  extracting: /content/images/00011618_009.png
#  extracting: /content/images/00014906_008.png
#  extracting: /content/images/00005954_006.png
#  extracting: /content/images/00008666_000.png
#  extracting: /content/images/00030183_004.png
#  extracting: /content/images/00026037_000.png
#  extracting: /content/images/00019765_012.png
#  extracting: /content/images/00029703_004.png
#  extracting: /content/images/00027584_011.png
#  extracting: /content/images/00023376_000.png
#  extracting: /content/images/00017504_059_aug_243_aug_66.png
#  extracting: /content/images/00021321_020.png
#  extracting: /content/images/00016064_013.png
#  extracting: /content/images/00018366_062.png
#  extracting: /content/images/00001790_000.png
#  extracting: /content/images/00002066_005.png
#  extracting: /content/images/00018419_001.png
#  extracting: /content/images/00012476_010.png
#  extracting: /content/images/00009691_003.png
#  extracting: /content/images/00025695_005.png
#  extracting: /content/images/00018166_000.png
#  extracting: /content/images/00010326_002.png
#  extracting: /content/images/00010971_000.png
#  extracting: /content/images/00014525_023.png
#  extracting: /content/images/00002359_013.png
#  extracting: /content/images/00007148_000.png
#  extracting: /content/images/00009323_003.png
#  extracting: /content/images/00026333_000.png
#  extracting: /content/images/00005992_000.png
#  extracting: /content/images/00008793_003.png
#  extracting: /content/images/00013849_019.png
#  extracting: /content/images/00020965_003.png
#  extracting: /content/images/00012304_005.png
#  extracting: /content/images/00000177_003.png
#  extracting: /content/images/00011831_015.png
#  extracting: /content/images/00013249_000.png
#  extracting: /content/images/00001985_000.png
#  extracting: /content/images/00022369_003.png
#  extracting: /content/images/00018592_000.png
#  extracting: /content/images/00023297_015.png
#  extracting: /content/images/00008420_002.png
#  extracting: /content/images/00017517_000.png
#  extracting: /content/images/00016821_004.png
#  extracting: /content/images/00013662_005.png
#  extracting: /content/images/00014176_003.png
#  extracting: /content/images/00027220_000.png
#  extracting: /content/images/00019850_000_aug_29.png
#  extracting: /content/images/00020159_005.png
#  extracting: /content/images/00025763_001.png
#  extracting: /content/images/00018260_003.png
#  extracting: /content/images/00012884_004.png
#  extracting: /content/images/00026607_000.png
#  extracting: /content/images/00007313_002.png
#  extracting: /content/images/00028384_001.png
#  extracting: /content/images/00023137_001.png
#  extracting: /content/images/00030496_003.png
#  extracting: /content/images/00012087_055.png
#  extracting: /content/images/00005400_003.png
#  extracting: /content/images/00007627_005.png
#  extracting: /content/images/00001946_003.png
#  extracting: /content/images/00027770_000.png
#  extracting: /content/images/00006070_007.png
#  extracting: /content/images/00016327_001.png
#  extracting: /content/images/00011959_003.png
#  extracting: /content/images/00002784_001.png
#  extracting: /content/images/00015871_000_aug_262.png
#  extracting: /content/images/00025781_001.png
#  extracting: /content/images/00030607_002.png
#  extracting: /content/images/00015690_000.png
#  extracting: /content/images/00017961_013.png
#  extracting: /content/images/00002843_010.png
#  extracting: /content/images/00020294_003.png
#  extracting: /content/images/00023865_000.png
#  extracting: /content/images/00013003_001.png
#  extracting: /content/images/00011237_035.png
#  extracting: /content/images/00008515_005.png
#  extracting: /content/images/00006641_001.png
#  extracting: /content/images/00013670_007.png
#  extracting: /content/images/00016669_002.png
#  extracting: /content/images/00022290_008.png
#  extracting: /content/images/00001549_014.png
#  extracting: /content/images/00017158_010.png
#  extracting: /content/images/00004383_000.png
#  extracting: /content/images/00009363_000.png
#  extracting: /content/images/00008085_000.png
#  extracting: /content/images/00006230_006.png
#  extracting: /content/images/00003719_007.png
#  extracting: /content/images/00029821_014.png
#  extracting: /content/images/00004843_008.png
#  extracting: /content/images/00029715_002.png
#  extracting: /content/images/00020373_000.png
#  extracting: /content/images/00015964_004.png
#  extracting: /content/images/00011770_002.png
#  extracting: /content/images/00018127_001.png
#  extracting: /content/images/00006875_022.png
#  extracting: /content/images/00004081_000.png
#  extracting: /content/images/00030178_011.png
#  extracting: /content/images/00009907_001.png
#  extracting: /content/images/00003027_003.png
#  extracting: /content/images/00020779_002.png
#  extracting: /content/images/00006980_005.png
#  extracting: /content/images/00026692_000.png
#  extracting: /content/images/00005822_000.png
#  extracting: /content/images/00008008_048.png
#  extracting: /content/images/00021902_000_aug_1452.png
#  extracting: /content/images/00016719_002.png
#  extracting: /content/images/00015895_002.png
#  extracting: /content/images/00015605_044.png
#  extracting: /content/images/00015606_018.png
#  extracting: /content/images/00003336_000.png
#  extracting: /content/images/00025191_002.png
#  extracting: /content/images/00028939_021.png
#  extracting: /content/images/00002139_002.png
#  extracting: /content/images/00001028_001.png
#  extracting: /content/images/00012049_003.png
#  extracting: /content/images/00015614_005.png
#  extracting: /content/images/00024601_000.png
#  extracting: /content/images/00019466_005.png
#  extracting: /content/images/00017253_000.png

# %%
# Import necessary packages
import keras
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import shap
import os
import seaborn as sns
import time
import pickle

# %%
train_df = pd.read_csv('/content/train_df.csv')
val_df = pd.read_csv('/content/val_df.csv')
test_df = pd.read_csv('/content/test_df.csv')
print(f"Train shape: {train_df.shape}")
print(f"Validation shape: {val_df.shape}")
print(f"Test shape: {test_df.shape}")
# Out:
# Train shape: (58045, 16)
# Validation shape: (17063, 16)
# Test shape: (16491, 16)

# %% [markdown]
# ### Analisis de una imagen

# %%
sample_img = train_df.Image_file[0]
raw_image = plt.imread(os.path.join(img_dir, sample_img))
plt.imshow(raw_image, cmap='gray')
plt.grid(color='w', linestyle='-', linewidth=1)
plt.colorbar()
plt.title('Imagen de rayos X de tórax sin procesar')
print(f"Las dimensiones de la imagen son {raw_image.shape[0]}  píxeles de ancho y {raw_image.shape[1]} píxeles de alto,con un solo canal de color")
# Out:
# Las dimensiones de la imagen son 320  píxeles de ancho y 320 píxeles de alto,con un solo canal de color

# %%
pixels = np.reshape(raw_image,raw_image.shape[0]*raw_image.shape[1])
plt.hist(pixels, bins=50, label=f'Media de los píxeles  {np.mean(raw_image):.4f} y desviación estándar  {np.std(raw_image):.4f}')
plt.legend(loc='upper center')
plt.title('Distribución de intensidades de píxeles en la imagen')
plt.xlabel('Intensidad de píxeles')
plt.ylabel('# Píxeles en la imagen')
plt.show()

# %% [markdown]
# # Preprocesamiento de imágenes en Keras
# ### Estandarización
#
# La normalización de imágenes es una de las más adecuadas para entrenar una red neuronal convolucional. Para esta tarea utilizamos la función ImageDataGenerator de Keras para realizar el preprocesamiento y el aumento de datos.
#
# El `image_generator` ajustará los datos de la imagen de modo que la nueva media de los datos sea cero y la desviación estándar de los datos sea 1.
#
# En otras palabras, el generador reemplazará cada valor de píxel en la imagen con un nuevo valor calculado restando la media y dividiéndolo por la desviación estándar.
#
# $$\frac{x_i - \mu}{\sigma}$$
#
# Se creo un generador de imágenes para el preprocesamiento.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def get_train_generator(df, image_dir, x_col, y_cols, shuffle=True, batch_size=8, seed=1, target_w = 320, target_h = 320):
    """
    Return generator for training set, normalizing using batch
    statistics.

    Args:
      train_df (dataframe): dataframe specifying training data.
      image_dir (str): directory where image files are held.
      x_col (str): name of column in df that holds filenames.
      y_cols (list): list of strings that hold y labels for images.
      batch_size (int): images per batch to be fed into model during training.
      seed (int): random seed.
      target_w (int): final width of input images.
      target_h (int): final height of input images.

    Returns:
        train_generator (DataFrameIterator): iterator over training set
    """
    # Normalize images  --- Generate batches of tensor image data with real-time data augmentation
    image_generator = ImageDataGenerator(
        samplewise_center=True,              #Set each sample mean to 0
        samplewise_std_normalization= True)  # Divide each input by its standard deviation

    print("\Generador de datos de entrenamiento...")
    generator = image_generator.flow_from_dataframe(
            dataframe=df,
            directory=image_dir,
            x_col=x_col,
            y_col=y_cols,
            class_mode="raw",       #  Mode for yielding the targets, one of "binary", "categorical", "input", "multi_output", "raw", sparse" or None. Default: "categorical".
            batch_size=batch_size,
            shuffle=shuffle,
            seed=seed,
            target_size=(target_w,target_h))

    return generator

# %%
def get_test_and_valid_generator(valid_df, test_df, train_df, image_dir, x_col, y_cols, sample_size=100, batch_size=8,
                                 seed=1, target_w = 320, target_h = 320):
    """
    Return generator for validation set and test test set using
    normalization statistics from training set.

    Args:
      valid_df (dataframe): dataframe specifying validation data.
      test_df (dataframe): dataframe specifying test data.
      train_df (dataframe): dataframe specifying training data.
      image_dir (str): directory where image files are held.
      x_col (str): name of column in df that holds filenames.
      y_cols (list): list of strings that hold y labels for images.
      sample_size (int): size of sample to use for normalization statistics.
      batch_size (int): images per batch to be fed into model during training.
      seed (int): random seed.
      target_w (int): final width of input images.
      target_h (int): final height of input images.

    Returns:
        test_generator (DataFrameIterator) and valid_generator: iterators over test set and validation set respectively
    """
    # get generator to sample dataset
    print(f"\nextracting {sample_size} train images to normalize validation and test datasets...")

    raw_train_generator = ImageDataGenerator().flow_from_dataframe(
        dataframe=train_df,
        directory=IMAGE_DIR,
        x_col=x_col,
        y_col=labels,
        class_mode="raw",
        batch_size=sample_size,
        shuffle=True,
        target_size=(target_w, target_h))

    # get data sample
    batch = raw_train_generator.__next__() # generate a batch of samples and associated labels
    data_sample = batch[0]             # => we need only the sample imgs ie batch[0]

    # use sample to fit mean and std for test set generator
    image_generator = ImageDataGenerator(
        featurewise_center=True,
        featurewise_std_normalization= True)

    # fit generator to sample from training data - we use this generator normalizing mean and std using the train sample of 100
    image_generator.fit(data_sample)

    print("\Generador de datos de validación...")

    # get test generator
    valid_generator = image_generator.flow_from_dataframe(
            dataframe=valid_df,
            directory=image_dir,
            x_col=x_col,
            y_col=y_cols,
            class_mode="raw",
            batch_size=batch_size,
            shuffle=False,
            seed=seed,
            target_size=(target_w,target_h))

    print("\Generador de datos de testeo...")

    test_generator = image_generator.flow_from_dataframe(
            dataframe=test_df,
            directory=image_dir,
            x_col=x_col,
            y_col=y_cols,
            class_mode="raw",
            batch_size=batch_size,
            shuffle=False,
            seed=seed,
            target_size=(target_w,target_h))
    return valid_generator, test_generator

# %%
labels = ['Cardiomegaly', 'Emphysema', 'Effusion', 'Hernia', 'Infiltration', 'Mass', 'Nodule', 'Atelectasis',
              'Pneumothorax', 'Pleural_Thickening', 'Pneumonia', 'Fibrosis', 'Edema', 'Consolidation']
IMAGE_DIR = "images"
train_generator = get_train_generator(train_df, IMAGE_DIR, "Image_file", labels)
valid_generator, test_generator= get_test_and_valid_generator(val_df, test_df, train_df, IMAGE_DIR, "Image_file", labels)
# Out:
# \Generador de datos de entrenamiento...
# Found 58045 validated image filenames.
#
# extracting 100 train images to normalize validation and test datasets...
# Found 58045 validated image filenames.
# \Generador de datos de validación...
# Found 17063 validated image filenames.
# \Generador de datos de testeo...
# Found 16491 validated image filenames.

# %%
plt.xticks(rotation=90)
plt.bar(x=labels, height=np.mean(train_generator.labels, axis=0))
plt.title("Distribución por clase en el entrenamiento")
plt.show()

# %%
# Plot a processed image
sns.set_style("white")
generated_image, label = train_generator.__getitem__(0)
plt.imshow(generated_image[0], cmap='gray')
plt.colorbar()
plt.title('Imagen de rayos X de tórax sin procesar')
print(f"Las dimensiones de la imagen son {generated_image.shape[1]}  píxeles de ancho y {generated_image.shape[2]} píxeles de alto")
print(f"El valor máximo de píxeles es {generated_image.max():.4f} y el mínimo es {generated_image.min():.4f}")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9701089..1.8660284].
# Las dimensiones de la imagen son 320  píxeles de ancho y 320 píxeles de alto
# El valor máximo de píxeles es 2.2033 y el mínimo es -2.2902

# %%
# Include a histogram of the distribution of the pixels
sns.set()
plt.figure(figsize=(10, 7))

# Plot histogram for original iamge
sns.distplot(raw_image.ravel(),
             label=f'Imagen original: media {np.mean(raw_image):.4f} - Desviación estándar {np.std(raw_image):.4f} \n '
             f'Valor mínimo de pixel {np.min(raw_image):.4} - Valor máximo del pixel {np.max(raw_image):.4}',
             color='blue',
             kde=False)

# Plot histogram for generated image
sns.distplot(generated_image[0].ravel(),
             label=f'Imagen generada: media {np.mean(generated_image[0]):.4f} - Desviación estándar {np.std(generated_image[0]):.4f} \n'
             f'Valor mínimo de pixel {np.min(generated_image[0]):.4} -Valor máximo del pixel {np.max(generated_image[0]):.4}',
             color='red',
             kde=False)

# Place legends
plt.legend()
plt.title('Distribucion de la intensidad de los pixeles en la imagen')
plt.xlabel('Intensidad del pixel')
plt.ylabel('# Pixel')
plt.show()
# Out:
# <ipython-input-15-8fb6d0546a56>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(raw_image.ravel(),
# <ipython-input-15-8fb6d0546a56>:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(generated_image[0].ravel(),

# %% [markdown]
# # Mobilenet v2

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import roc_auc_score
import tensorflow as tf
# Define the model with transfer learning
def get_model_pretrained(num_classes, weights='imagenet', trainable=True):
    base_model = MobileNetV2(weights=weights, include_top=False, input_shape=(320, 320, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    if trainable:
      for layer in base_model.layers:
        layer.trainable = True
    else:
        for layer in base_model.layers:
           layer.trainable = False

    return model

# Define the model without transfer learning and without pretrained weights
def get_model_no_transfer_no_pretrained(num_classes):
    base_model = MobileNetV2(weights=None, include_top=False, input_shape=(320, 320, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    return model

# Define the model from scratch
def get_model_from_scratch(num_classes):
  model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(320,320,3)),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes, activation='sigmoid')
  ])
  return model

# Compile and train the model
def compile_and_train_model(model, train_generator, valid_generator, epochs=10, learning_rate=0.0001):
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['AUC'])

    # Reduce learning rate when a metric has stopped improving.
    lr_reducer = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000001, monitor='val_auc', verbose=1)
    # Save the model after every epoch.
    checkpoint = ModelCheckpoint(filepath='best_weights.keras', save_best_only=True, monitor='val_auc', verbose=1)

    history = model.fit(
      x=train_generator,
      validation_data=valid_generator,
      epochs=epochs,
      callbacks=[lr_reducer, checkpoint]
    )
    return history, model

def evaluate_model(model, test_generator):
  # Evaluate
  y_true = test_generator.labels
  y_pred = model.predict(test_generator, verbose=1)
  roc_auc = roc_auc_score(y_true, y_pred)
  print(f'ROC AUC: {roc_auc:.4f}')

  return roc_auc


num_classes = len(labels)
epochs = 5
learning_rate = 0.0001

# %%
print("Entrenando red con transfer learning...")
model_transfer_learning = get_model_pretrained(num_classes)
history_transfer_learning, model_transfer_learning = compile_and_train_model(model_transfer_learning, train_generator, valid_generator, epochs, learning_rate)
roc_auc_transfer_learning = evaluate_model(model_transfer_learning, test_generator)
# Out:
# Entrenando red con transfer learning...
# <ipython-input-9-5ebf0cdc1d5b>:10: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights=weights, include_top=False, input_shape=(320, 320, 3))
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 667s 84ms/step - AUC: 0.7263 - loss: 0.1133 - val_AUC: 0.7854 - val_loss: 0.1924 - learning_rate: 1.0000e-04
# Epoch 2/5
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_auc` which is not available. Available metrics are: AUC,loss,val_AUC,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/model_checkpoint.py:209: UserWarning: Can save best model only with val_auc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 652s 84ms/step - AUC: 0.8165 - loss: 0.0976 - val_AUC: 0.7942 - val_loss: 0.1886 - learning_rate: 1.0000e-04
# Epoch 3/5
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 564s 78ms/step - AUC: 0.8435 - loss: 0.0930 - val_AUC: 0.8052 - val_loss: 0.1866 - learning_rate: 1.0000e-04
# Epoch 4/5
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 566s 78ms/step - AUC: 0.8669 - loss: 0.0894 - val_AUC: 0.8048 - val_loss: 0.2041 - learning_rate: 1.0000e-04
# Epoch 5/5
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 567s 78ms/step - AUC: 0.8858 - loss: 0.0841 - val_AUC: 0.8062 - val_loss: 0.1769 - learning_rate: 1.0000e-04
# 2062/2062 ━━━━━━━━━━━━━━━━━━━━ 112s 52ms/step
# ROC AUC: 0.7962

# %%
model_transfer_learning.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 320, 320, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 160, 160, 32)   │            864 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 160, 160, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 160, 160, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 160, 160, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 160, 160, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 160, 160, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 160, 160, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 160, 160, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 160, 160, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 160, 160, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 160, 160, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 161, 161, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 80, 80, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 80, 80, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 80, 80, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 80, 80, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 80, 80, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 80, 80, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 80, 80, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 80, 80, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 80, 80, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 80, 80, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 80, 80, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 80, 80, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 80, 80, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 80, 80, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 80, 80, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 80, 80, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 80, 80, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 81, 81, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 40, 40, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 40, 40, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 40, 40, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 40, 40, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 40, 40, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 40, 40, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 40, 40, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 40, 40, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 40, 40, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 40, 40, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 40, 40, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 40, 40, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 40, 40, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 40, 40, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 40, 40, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 40, 40, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 40, 40, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 40, 40, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 40, 40, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 40, 40, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 40, 40, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 40, 40, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 40, 40, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 40, 40, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 40, 40, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 40, 40, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 41, 41, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 20, 20, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 20, 20, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 20, 20, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 20, 20, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 20, 20, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 20, 20, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 20, 20, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 20, 20, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 20, 20, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 20, 20, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 20, 20, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 20, 20, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 20, 20, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 20, 20, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 20, 20, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 20, 20, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 20, 20, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 20, 20, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 20, 20, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 20, 20, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 20, 20, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 20, 20, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 20, 20, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 20, 20, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 20, 20, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 20, 20, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 20, 20, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 20, 20, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 20, 20, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 20, 20, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 20, 20, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 20, 20, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 20, 20, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 20, 20, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 20, 20, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 20, 20, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 20, 20, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 20, 20, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 20, 20, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 20, 20, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 20, 20, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 20, 20, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 20, 20, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 20, 20, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 20, 20, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 20, 20, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 20, 20, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 20, 20, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 20, 20, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 20, 20, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 20, 20, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 20, 20, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 20, 20, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 20, 20, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 20, 20, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 20, 20, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 20, 20, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 20, 20, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 20, 20, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 20, 20, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 20, 20, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 21, 21, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 10, 10, 576)    │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 10, 10, 576)    │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 10, 10, 576)    │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 10, 10, 160)    │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 10, 10, 160)    │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 10, 10, 960)    │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 10, 10, 960)    │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 10, 10, 960)    │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 10, 10, 960)    │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 10, 10, 960)    │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 10, 10, 960)    │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 10, 10, 160)    │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 10, 10, 160)    │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 10, 10, 160)    │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 10, 10, 960)    │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 10, 10, 960)    │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 10, 10, 960)    │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 10, 10, 960)    │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 10, 10, 960)    │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 10, 10, 960)    │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 10, 10, 160)    │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 10, 10, 160)    │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 10, 10, 160)    │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 10, 10, 960)    │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 10, 10, 960)    │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 10, 10, 960)    │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 10, 10, 960)    │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 10, 10, 960)    │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 10, 10, 960)    │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 10, 10, 320)    │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 10, 10, 320)    │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 10, 10, 1280)   │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 10, 10, 1280)   │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 10, 10, 1280)   │              0 │ Conv_1_bn[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1280)           │              0 │ out_relu[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 1024)           │      1,311,744 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 1024)           │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 14)             │         14,350 │ dropout_2[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 10,684,012 (40.76 MB)
#  Trainable params: 3,549,966 (13.54 MB)
#  Non-trainable params: 34,112 (133.25 KB)
#  Optimizer params: 7,099,934 (27.08 MB)

# %%
print("Entrenando red sin los pesos de su preentrenamiento...")
model_no_transfer_no_pretrained = get_model_no_transfer_no_pretrained(num_classes)
history_no_transfer_no_pretrained, model_no_transfer_no_pretrained = compile_and_train_model(model_no_transfer_no_pretrained, train_generator, valid_generator, epochs, learning_rate)
roc_auc_no_transfer_no_pretrained = evaluate_model(model_no_transfer_no_pretrained, test_generator)
# Out:
# Entrenando red sin los pesos de su preentrenamiento...
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 699s 89ms/step - AUC: 0.6458 - loss: 0.1191 - val_AUC: 0.6556 - val_loss: 0.2002 - learning_rate: 1.0000e-04
# Epoch 2/5
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_auc` which is not available. Available metrics are: AUC,loss,val_AUC,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/model_checkpoint.py:209: UserWarning: Can save best model only with val_auc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 589s 81ms/step - AUC: 0.7059 - loss: 0.1098 - val_AUC: 0.7118 - val_loss: 0.2076 - learning_rate: 1.0000e-04
# Epoch 3/5
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 586s 81ms/step - AUC: 0.7349 - loss: 0.1082 - val_AUC: 0.7066 - val_loss: 0.2055 - learning_rate: 1.0000e-04
# Epoch 4/5
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 583s 80ms/step - AUC: 0.7470 - loss: 0.1069 - val_AUC: 0.6886 - val_loss: 0.2074 - learning_rate: 1.0000e-04
# Epoch 5/5
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 577s 79ms/step - AUC: 0.7648 - loss: 0.1040 - val_AUC: 0.7363 - val_loss: 0.2046 - learning_rate: 1.0000e-04
# 2062/2062 ━━━━━━━━━━━━━━━━━━━━ 115s 54ms/step
# ROC AUC: 0.6703

# %%
model_no_transfer_no_pretrained.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 320, 320, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 160, 160, 32)   │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 160, 160, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 160, 160, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 160, 160, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 160, 160, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 160, 160, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 160, 160, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 160, 160, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 160, 160, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 160, 160, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 160, 160, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 161, 161, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 80, 80, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 80, 80, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 80, 80, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 80, 80, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 80, 80, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 80, 80, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 80, 80, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 80, 80, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 80, 80, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 80, 80, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 80, 80, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 80, 80, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 80, 80, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 80, 80, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 80, 80, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 80, 80, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 80, 80, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 81, 81, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 40, 40, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 40, 40, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 40, 40, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 40, 40, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 40, 40, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 40, 40, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 40, 40, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 40, 40, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 40, 40, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 40, 40, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 40, 40, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 40, 40, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 40, 40, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 40, 40, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 40, 40, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 40, 40, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 40, 40, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 40, 40, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 40, 40, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 40, 40, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 40, 40, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 40, 40, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 40, 40, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 40, 40, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 40, 40, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 40, 40, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 41, 41, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 20, 20, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 20, 20, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 20, 20, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 20, 20, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 20, 20, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 20, 20, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 20, 20, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 20, 20, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 20, 20, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 20, 20, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 20, 20, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 20, 20, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 20, 20, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 20, 20, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 20, 20, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 20, 20, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 20, 20, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 20, 20, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 20, 20, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 20, 20, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 20, 20, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 20, 20, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 20, 20, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 20, 20, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 20, 20, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 20, 20, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 20, 20, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 20, 20, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 20, 20, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 20, 20, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 20, 20, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 20, 20, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 20, 20, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 20, 20, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 20, 20, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 20, 20, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 20, 20, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 20, 20, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 20, 20, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 20, 20, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 20, 20, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 20, 20, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 20, 20, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 20, 20, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 20, 20, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 20, 20, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 20, 20, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 20, 20, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 20, 20, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 20, 20, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 20, 20, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 20, 20, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 20, 20, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 20, 20, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 20, 20, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 20, 20, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 20, 20, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 20, 20, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 20, 20, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 20, 20, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 20, 20, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 21, 21, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 10, 10, 576)    │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 10, 10, 576)    │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 10, 10, 576)    │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 10, 10, 160)    │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 10, 10, 160)    │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 10, 10, 960)    │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 10, 10, 960)    │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 10, 10, 960)    │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 10, 10, 960)    │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 10, 10, 960)    │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 10, 10, 960)    │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 10, 10, 160)    │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 10, 10, 160)    │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 10, 10, 160)    │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 10, 10, 960)    │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 10, 10, 960)    │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 10, 10, 960)    │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 10, 10, 960)    │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 10, 10, 960)    │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 10, 10, 960)    │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 10, 10, 160)    │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 10, 10, 160)    │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 10, 10, 160)    │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 10, 10, 960)    │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 10, 10, 960)    │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 10, 10, 960)    │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 10, 10, 960)    │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 10, 10, 960)    │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 10, 10, 960)    │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 10, 10, 320)    │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 10, 10, 320)    │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 10, 10, 1280)   │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 10, 10, 1280)   │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 10, 10, 1280)   │              0 │ Conv_1_bn[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1280)           │              0 │ out_relu[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1024)           │      1,311,744 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 1024)           │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 14)             │         14,350 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 10,684,012 (40.76 MB)
#  Trainable params: 3,549,966 (13.54 MB)
#  Non-trainable params: 34,112 (133.25 KB)
#  Optimizer params: 7,099,934 (27.08 MB)

# %%
print("Entrenando red creada desde cero...")
model_from_scratch = get_model_from_scratch(num_classes)
history_from_scratch, model_from_scratch = compile_and_train_model(model_from_scratch, train_generator, valid_generator, epochs, learning_rate)
roc_auc_from_scratch = evaluate_model(model_from_scratch, test_generator)
# Out:
# Entrenando red creada desde cero...
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 449s 61ms/step - AUC: 0.6120 - loss: 0.1427 - val_AUC: 0.7062 - val_loss: 0.1985 - learning_rate: 1.0000e-04
# Epoch 2/5
#    1/7256 ━━━━━━━━━━━━━━━━━━━━ 12:35 104ms/step - AUC: 0.6318 - loss: 0.1034
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_auc` which is not available. Available metrics are: AUC,loss,val_AUC,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/model_checkpoint.py:209: UserWarning: Can save best model only with val_auc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 409s 56ms/step - AUC: 0.7095 - loss: 0.1105 - val_AUC: 0.7303 - val_loss: 0.1930 - learning_rate: 1.0000e-04
# Epoch 3/5
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 386s 53ms/step - AUC: 0.7563 - loss: 0.1068 - val_AUC: 0.7271 - val_loss: 0.2013 - learning_rate: 1.0000e-04
# Epoch 4/5
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 389s 54ms/step - AUC: 0.8011 - loss: 0.1009 - val_AUC: 0.7218 - val_loss: 0.1933 - learning_rate: 1.0000e-04
# Epoch 5/5
# 7256/7256 ━━━━━━━━━━━━━━━━━━━━ 452s 62ms/step - AUC: 0.8508 - loss: 0.0918 - val_AUC: 0.6961 - val_loss: 0.2245 - learning_rate: 1.0000e-04
# 2062/2062 ━━━━━━━━━━━━━━━━━━━━ 92s 44ms/step
# ROC AUC: 0.6501

# %%
model_from_scratch.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 320, 320, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 160, 160, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 160, 160, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 80, 80, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 80, 80, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 40, 40, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 204800)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │      26,214,528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 14)                  │           1,806 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 78,928,748 (301.09 MB)
#  Trainable params: 26,309,582 (100.36 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 52,619,166 (200.73 MB)

# %%
import pickle
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

models = {
    "Transfer Learning": model_transfer_learning,
    "No Transfer No Pretrained": model_no_transfer_no_pretrained,
    "From Scratch": model_from_scratch
}

drive_model_dir = '/content/drive/MyDrive/saved_models'
os.makedirs(drive_model_dir, exist_ok=True)

# Save each model to a separate file in Google Drive
for model_name, model in models.items():
    model_path = os.path.join(drive_model_dir, f'{model_name}.pkl')
    with open(model_path, 'wb') as f:
        pickle.dump(model, f)

print(f"Modelos salvados en '{drive_model_dir}' en Google Drive.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Modelos salvados en '/content/drive/MyDrive/saved_models' en Google Drive.
